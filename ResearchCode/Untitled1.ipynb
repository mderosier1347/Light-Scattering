# %%
import numpy as np
import matplotlib.pyplot as plt

fracT = np.array([0.1124,0.0439,0.0279])
lnT = np.array([2.186,3.127,3.581])

m,b = np.polyfit(fracT,lnT,1)

print('Slope: ', m)
print('Intercept: ',b)

plt.plot(fracT,lnT)
plt.xlabel('1/T (1/K)')
plt.ylabel('ln(K)')
plt.show()
# Out:
# Slope:  -15.68432808040701
# Intercept:  3.9276844108036553
